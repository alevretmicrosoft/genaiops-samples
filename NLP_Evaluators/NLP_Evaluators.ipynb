# %% [markdown]
# # Evaluate with quantitative NLP evaluators
#
# ## Objective
# This notebook demonstrates how to use NLP-based evaluators to assess the quality of generated text by comparing it to reference text. By the end of this tutorial, you'll be able to:
#  - Understand different NLP evaluators such as `BleuScoreEvaluator`, `GleuScoreEvaluator`, `MeteorScoreEvaluator`, and `RougeScoreEvaluator`.
#  - Evaluate dataset using these evaluators.
#
# ## Time
# You should expect to spend about 10 minutes running this notebook.
#
# ## Before you begin
#
# ### Installation
# Install the following packages required to execute this notebook.

# %%
# Install the packages
# %pip install azure-ai-evaluation
# Out:
# Requirement already satisfied: azure-ai-evaluation in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: promptflow-devkit>=1.15.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: promptflow-core>=1.15.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (2.9.0)
# Requirement already satisfied: azure-identity>=1.16.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (1.19.0)
# Requirement already satisfied: azure-core>=1.30.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (1.32.0)
# Requirement already satisfied: nltk>=3.9.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\alevret\appdata\roaming\python\python312\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (43.0.1)
# Requirement already satisfied: msal>=1.30.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: click in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: joblib in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: docstring_parser in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.115.6)
# Requirement already satisfied: filetype>=1.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (4.20.0)
# Requirement already satisfied: promptflow-tracing==1.17.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: psutil in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (5.9.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in c:\users\alevret\appdata\roaming\python\python312\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.18.10)
# Requirement already satisfied: openai in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.63.2)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.28.2)
# Requirement already satisfied: tiktoken>=0.4.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.8.0)
# Requirement already satisfied: argcomplete>=3.2.3 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.5.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.0b32)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\alevret\appdata\roaming\python\python312\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.16.1)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.0)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.21.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.28.2)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (10.3.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.1)
# Requirement already satisfied: pywin32 in c:\users\alevret\appdata\roaming\python\python312\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (306)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.31)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.26 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.28.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.10.4)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (9.0.1)
# Requirement already satisfied: pytz in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.1)
# Requirement already satisfied: importlib-resources in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (6.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.0.11)
# Requirement already satisfied: anyio in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.4.0)
# Requirement already satisfied: certifi in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.5)
# Requirement already satisfied: idna in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.18.1)
# Requirement already satisfied: jaraco.classes in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.2.3)
# Requirement already satisfied: packaging>=17.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.15.0->azure-ai-evaluation) (23.2)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from msal-extensions>=1.2.0->azure-identity>=1.16.0->azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.28.2)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-proto==1.28.2->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.28.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core>=1.15.0->azure-ai-evaluation) (0.2.8)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.0.3)
# Requirement already satisfied: pycparser in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (2.1.5)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (7.2.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.49b2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.27.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: more-itertools in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (10.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alevret\appdata\local\programs\python\python312\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alevret\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alevret\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alevret\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
azure_ai_project = {
    "subscription_id": "65a513ce-bb5d-4ed5-92b1-fa601d510a15",
    "resource_group_name": "agentai",
    "project_name": "eastus2project",
}

# %% [markdown]
# ## NLP Evaluators

# %% [markdown]
# ### BleuScoreEvaluator
#
# BLEU (Bilingual Evaluation Understudy) score is commonly used in natural language processing (NLP) and machine
# translation. It is widely used in text summarization and text generation use cases. It evaluates how closely the
# generated text matches the reference text. The BLEU score ranges from 0 to 1, with higher scores indicating
# better quality.

# %%
from azure.ai.evaluation import BleuScoreEvaluator

bleu = BleuScoreEvaluator()

# %%
result = bleu(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'bleu_score': 0.22961813530951883}

# %% [markdown]
# ### GleuScoreEvaluator
#
# The GLEU (Google-BLEU) score evaluator measures the similarity between generated and reference texts by
# evaluating n-gram overlap, considering both precision and recall. This balanced evaluation, designed for
# sentence-level assessment, makes it ideal for detailed analysis of translation quality. GLEU is well-suited for
# use cases such as machine translation, text summarization, and text generation.

# %%
from azure.ai.evaluation import GleuScoreEvaluator

gleu = GleuScoreEvaluator()

# %%
result = gleu(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'gleu_score': 0.4090909090909091}

# %% [markdown]
# ### MeteorScoreEvaluator
#
# The METEOR (Metric for Evaluation of Translation with Explicit Ordering) score grader evaluates generated text by
# comparing it to reference texts, focusing on precision, recall, and content alignment. It addresses limitations of
# other metrics like BLEU by considering synonyms, stemming, and paraphrasing. METEOR score considers synonyms and
# word stems to more accurately capture meaning and language variations. In addition to machine translation and
# text summarization, paraphrase detection is an optimal use case for the METEOR score.

# %%
from azure.ai.evaluation import MeteorScoreEvaluator

meteor = MeteorScoreEvaluator(alpha=0.9, beta=3.0, gamma=0.5)

# %%
result = meteor(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'meteor_score': 0.9067055393586005}

# %% [markdown]
# ### RougeScoreEvaluator
#
# ROUGE (Recall-Oriented Understudy for Gisting Evaluation) is a set of metrics used to evaluate automatic
# summarization and machine translation. It measures the overlap between generated text and reference summaries.
# ROUGE focuses on recall-oriented measures to assess how well the generated text covers the reference text. Text
# summarization and document comparison are among optimal use cases for ROUGE, particularly in scenarios where text
# coherence and relevance are critical.

# %%
from azure.ai.evaluation import RougeScoreEvaluator, RougeType

rouge = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)

# %%
result = rouge(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'rouge_precision': 1.0, 'rouge_recall': 1.0, 'rouge_f1_score': 1.0}

# %% [markdown]
# ## Evaluate a Dataset using Math Evaluators
#
# The code below uses the Evaluate API with BLEU, GLEU, METEOR, and ROUGE evaluators to evaluate the results on a dataset.

# %%
from azure.ai.evaluation import evaluate

result = evaluate(
    data="data.jsonl",
    evaluators={
        "bleu": bleu,
        "gleu": gleu,
        "meteor": meteor,
        "rouge": rouge,
    },
    # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI Studio project
    azure_ai_project=azure_ai_project,
)
# Out:
# [2025-02-20 10:44:06 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-20 10:44:06 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-20 10:44:06 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-20 10:44:06 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-20 10:44:06 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209\logs.txt
# [2025-02-20 10:44:06 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209\logs.txt
# [2025-02-20 10:44:06 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209\logs.txt
# [2025-02-20 10:44:06 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209, log path: C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209\logs.txt
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209
# 2025-02-20 10:44:07 +0000    6672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-20 10:44:09 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:09 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.04 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209"
# Run status: "Completed"
# Start time: "2025-02-20 10:44:06.551111+00:00"
# Duration: "0:00:05.210473"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209"
#
# 2025-02-20 10:44:12 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:12 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.11 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.12 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.13 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-20 10:44:07 +0000    6672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-20 10:44:12 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:12 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.11 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209"
# Run status: "Completed"
# Start time: "2025-02-20 10:44:06.552113+00:00"
# Duration: "0:00:07.182412"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209"
#
# 2025-02-20 10:44:07 +0000    6672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.12 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209"
# Run status: "Completed"
# Start time: "2025-02-20 10:44:06.553506+00:00"
# Duration: "0:00:08.181765"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209"
#
# 2025-02-20 10:44:07 +0000    6672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Finished 50 / 50 lines.
# 2025-02-20 10:44:13 +0000    6672 execution.bulk     INFO     Average execution time for completed lines: 0.13 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209"
# Run status: "Completed"
# Start time: "2025-02-20 10:44:06.552113+00:00"
# Duration: "0:00:08.499702"
# Output path: "C:\Users\alevret\.promptflow\.runs\azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209"
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 1s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 2s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 4s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 8s.
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "bleu": {
#         "status": "Completed",
#         "duration": "0:00:08.181765",
#         "completed_lines": 50,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_a47_sbb3_20250220_104406_563209"
#     },
#     "gleu": {
#         "status": "Completed",
#         "duration": "0:00:07.182412",
#         "completed_lines": 50,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_1grqzfag_20250220_104406_563209"
#     },
#     "meteor": {
#         "status": "Completed",
#         "duration": "0:00:08.499702",
#         "completed_lines": 50,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_n6eu0g9a_20250220_104406_562209"
#     },
#     "rouge": {
#         "status": "Completed",
#         "duration": "0:00:05.210473",
#         "completed_lines": 50,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\alevret\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_7wmco0dk_20250220_104406_562209"
#     }
# }
#
# ====================================================

# %% [markdown]
# View the results

# %%
from pprint import pprint

pprint(result)
# Out:
# {'metrics': {'bleu.bleu_score': 0.27254923738000003,
#              'gleu.gleu_score': 0.40707292707600007,
#              'meteor.meteor_score': 0.8376872508759999,
#              'rouge.rouge_f1_score': 0.6787035187120002,
#              'rouge.rouge_precision': 0.661285714288,
#              'rouge.rouge_recall': 0.7116190476240001},
#  'rows': [{'inputs.ground_truth': 'A dog is barking loudly.',
#            'inputs.response': 'The dog barks loudly.',
#            'line_number': 0,
#            'outputs.bleu.bleu_score': 0.1098261402,
#            'outputs.gleu.gleu_score': 0.2222222222,
#            'outputs.meteor.meteor_score': 0.6355932203,
#            'outputs.rouge.rouge_f1_score': 0.4444444444,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.4},
#           {'inputs.ground_truth': 'They visited the beach.',
#            'inputs.response': 'They went to the beach.',
#            'line_number': 1,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.7352941176000001,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The sun shines brightly.',
#            'inputs.response': 'The sun is shining brightly.',
#            'line_number': 2,
#            'outputs.bleu.bleu_score': 0.13742926600000002,
#            'outputs.gleu.gleu_score': 0.33333333330000003,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'She prepared a tasty meal.',
#            'inputs.response': 'She cooked a delicious meal.',
#            'line_number': 3,
#            'outputs.bleu.bleu_score': 0.1155637771,
#            'outputs.gleu.gleu_score': 0.2777777778,
#            'outputs.meteor.meteor_score': 0.5260416667,
#            'outputs.rouge.rouge_f1_score': 0.6000000000000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.6000000000000001},
#           {'inputs.ground_truth': 'He reads the paper each morning.',
#            'inputs.response': 'He reads the newspaper every morning.',
#            'line_number': 4,
#            'outputs.bleu.bleu_score': 0.2427916178,
#            'outputs.gleu.gleu_score': 0.4090909091,
#            'outputs.meteor.meteor_score': 0.6914285714,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6666666667000001,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'Kids are playing in the park.',
#            'inputs.response': 'The children are playing in the park.',
#            'line_number': 5,
#            'outputs.bleu.bleu_score': 0.6803749333,
#            'outputs.gleu.gleu_score': 0.6923076923,
#            'outputs.meteor.meteor_score': 0.9844782984,
#            'outputs.rouge.rouge_f1_score': 0.7692307692,
#            'outputs.rouge.rouge_precision': 0.7142857143,
#            'outputs.rouge.rouge_recall': 0.8333333333},
#           {'inputs.ground_truth': 'The car is parked outside the house.',
#            'inputs.response': 'The car is parked outside.',
#            'line_number': 6,
#            'outputs.bleu.bleu_score': 0.5698363775,
#            'outputs.gleu.gleu_score': 0.5769230769,
#            'outputs.meteor.meteor_score': 0.7211538462,
#            'outputs.rouge.rouge_f1_score': 0.8333333333,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.7142857143},
#           {'inputs.ground_truth': 'She writes a letter.',
#            'inputs.response': 'She is writing a letter.',
#            'line_number': 7,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He watches a film.',
#            'inputs.response': 'He is watching a movie.',
#            'line_number': 8,
#            'outputs.bleu.bleu_score': 0.0494757029,
#            'outputs.gleu.gleu_score': 0.1666666667,
#            'outputs.meteor.meteor_score': 0.618872549,
#            'outputs.rouge.rouge_f1_score': 0.4444444444,
#            'outputs.rouge.rouge_precision': 0.4,
#            'outputs.rouge.rouge_recall': 0.5},
#           {'inputs.ground_truth': 'Flowers are in bloom.',
#            'inputs.response': 'The flowers are blooming.',
#            'line_number': 9,
#            'outputs.bleu.bleu_score': 0.054286939900000004,
#            'outputs.gleu.gleu_score': 0.1428571429,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.5,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.5},
#           {'inputs.ground_truth': 'They are enjoying a picnic.',
#            'inputs.response': 'They are having a picnic.',
#            'line_number': 10,
#            'outputs.bleu.bleu_score': 0.2939457035,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.8066666667,
#            'outputs.rouge.rouge_f1_score': 0.8,
#            'outputs.rouge.rouge_precision': 0.8,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'A baby is asleep.',
#            'inputs.response': 'The baby is sleeping.',
#            'line_number': 11,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.5111111111000001,
#            'outputs.rouge.rouge_f1_score': 0.5,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.5},
#           {'inputs.ground_truth': 'She paints a picture.',
#            'inputs.response': 'She is painting a picture.',
#            'line_number': 12,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He repairs the bike.',
#            'inputs.response': 'He is fixing the bike.',
#            'line_number': 13,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'A book is on the table.',
#            'inputs.response': 'The book is on the table.',
#            'line_number': 14,
#            'outputs.bleu.bleu_score': 0.8091067116,
#            'outputs.gleu.gleu_score': 0.8181818182,
#            'outputs.meteor.meteor_score': 0.8551587302,
#            'outputs.rouge.rouge_f1_score': 0.8333333333,
#            'outputs.rouge.rouge_precision': 0.8333333333,
#            'outputs.rouge.rouge_recall': 0.8333333333},
#           {'inputs.ground_truth': 'They dance together.',
#            'inputs.response': 'They are dancing together.',
#            'line_number': 15,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'The coffee is very hot.',
#            'inputs.response': 'The coffee is hot.',
#            'line_number': 16,
#            'outputs.bleu.bleu_score': 0.30834517980000004,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.8203389831000001,
#            'outputs.rouge.rouge_f1_score': 0.8888888889000001,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'She learns to swim.',
#            'inputs.response': 'She is learning to swim.',
#            'line_number': 17,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He plays the guitar.',
#            'inputs.response': 'He is playing the guitar.',
#            'line_number': 18,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The sky is clear and blue.',
#            'inputs.response': 'The sky is clear.',
#            'line_number': 19,
#            'outputs.bleu.bleu_score': 0.4739878501,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.7117647059000001,
#            'outputs.rouge.rouge_f1_score': 0.8,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'They build a sandcastle.',
#            'inputs.response': 'They are building a sandcastle.',
#            'line_number': 20,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The pizza is done.',
#            'inputs.response': 'The pizza is ready.',
#            'line_number': 21,
#            'outputs.bleu.bleu_score': 0.3218442408,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'She reads a novel.',
#            'inputs.response': 'She is reading a novel.',
#            'line_number': 22,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He drives a car.',
#            'inputs.response': 'He is driving a car.',
#            'line_number': 23,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The water is chilly.',
#            'inputs.response': 'The water is cold.',
#            'line_number': 24,
#            'outputs.bleu.bleu_score': 0.3218442408,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'They sing a song.',
#            'inputs.response': 'They are singing a song.',
#            'line_number': 25,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The cake tastes great.',
#            'inputs.response': 'The cake is delicious.',
#            'line_number': 26,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.5111111111000001,
#            'outputs.rouge.rouge_f1_score': 0.5,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.5},
#           {'inputs.ground_truth': 'She knits a scarf.',
#            'inputs.response': 'She is knitting a scarf.',
#            'line_number': 27,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He jogs in the park.',
#            'inputs.response': 'He is jogging in the park.',
#            'line_number': 28,
#            'outputs.bleu.bleu_score': 0.4347208719,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.9653916211,
#            'outputs.rouge.rouge_f1_score': 0.7272727273,
#            'outputs.rouge.rouge_precision': 0.6666666667000001,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'The room is tidy.',
#            'inputs.response': 'The room is clean.',
#            'line_number': 29,
#            'outputs.bleu.bleu_score': 0.3218442408,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'They watch the sunset.',
#            'inputs.response': 'They are watching the sunset.',
#            'line_number': 30,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The soup is steaming.',
#            'inputs.response': 'The soup is hot.',
#            'line_number': 31,
#            'outputs.bleu.bleu_score': 0.3218442408,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'She plants flowers.',
#            'inputs.response': 'She is planting flowers.',
#            'line_number': 32,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'He reads a magazine.',
#            'inputs.response': 'He is reading a magazine.',
#            'line_number': 33,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The ice cream melts.',
#            'inputs.response': 'The ice cream is melting.',
#            'line_number': 34,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'They play chess.',
#            'inputs.response': 'They are playing chess.',
#            'line_number': 35,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'The bread is freshly baked.',
#            'inputs.response': 'The bread is fresh.',
#            'line_number': 36,
#            'outputs.bleu.bleu_score': 0.2635037776,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.6355932203,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.6000000000000001},
#           {'inputs.ground_truth': 'She sews a dress.',
#            'inputs.response': 'She is sewing a dress.',
#            'line_number': 37,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'He fishes at the lake.',
#            'inputs.response': 'He is fishing at the lake.',
#            'line_number': 38,
#            'outputs.bleu.bleu_score': 0.4347208719,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.9653916211,
#            'outputs.rouge.rouge_f1_score': 0.7272727273,
#            'outputs.rouge.rouge_precision': 0.6666666667000001,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'The tea is warm and soothing.',
#            'inputs.response': 'The tea is warm.',
#            'line_number': 39,
#            'outputs.bleu.bleu_score': 0.4739878501,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.7117647059000001,
#            'outputs.rouge.rouge_f1_score': 0.8,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'They hike in the mountains.',
#            'inputs.response': 'They are hiking in the mountains.',
#            'line_number': 40,
#            'outputs.bleu.bleu_score': 0.4347208719,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.9653916211,
#            'outputs.rouge.rouge_f1_score': 0.7272727273,
#            'outputs.rouge.rouge_precision': 0.6666666667000001,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'The music is very loud.',
#            'inputs.response': 'The music is loud.',
#            'line_number': 41,
#            'outputs.bleu.bleu_score': 0.30834517980000004,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.8203389831000001,
#            'outputs.rouge.rouge_f1_score': 0.8888888889000001,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'She bakes cookies.',
#            'inputs.response': 'She is baking cookies.',
#            'line_number': 42,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'He plays basketball.',
#            'inputs.response': 'He is playing basketball.',
#            'line_number': 43,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'The wind is very strong.',
#            'inputs.response': 'The wind is strong.',
#            'line_number': 44,
#            'outputs.bleu.bleu_score': 0.30834517980000004,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.8203389831000001,
#            'outputs.rouge.rouge_f1_score': 0.8888888889000001,
#            'outputs.rouge.rouge_precision': 1.0,
#            'outputs.rouge.rouge_recall': 0.8},
#           {'inputs.ground_truth': 'They study for exams.',
#            'inputs.response': 'They are studying for exams.',
#            'line_number': 45,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The film is interesting.',
#            'inputs.response': 'The movie is interesting.',
#            'line_number': 46,
#            'outputs.bleu.bleu_score': 0.3218442408,
#            'outputs.gleu.gleu_score': 0.5,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'She practices yoga.',
#            'inputs.response': 'She is practicing yoga.',
#            'line_number': 47,
#            'outputs.bleu.bleu_score': 0.1341419505,
#            'outputs.gleu.gleu_score': 0.2857142857,
#            'outputs.meteor.meteor_score': 0.9146341463000001,
#            'outputs.rouge.rouge_f1_score': 0.5714285714,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_recall': 0.6666666667000001},
#           {'inputs.ground_truth': 'He writes a report.',
#            'inputs.response': 'He is writing a report.',
#            'line_number': 48,
#            'outputs.bleu.bleu_score': 0.2511983594,
#            'outputs.gleu.gleu_score': 0.3888888889,
#            'outputs.meteor.meteor_score': 0.9490196078,
#            'outputs.rouge.rouge_f1_score': 0.6666666667000001,
#            'outputs.rouge.rouge_precision': 0.6000000000000001,
#            'outputs.rouge.rouge_recall': 0.75},
#           {'inputs.ground_truth': 'The garden looks beautiful.',
#            'inputs.response': 'The garden is beautiful.',
#            'line_number': 49,
#            'outputs.bleu.bleu_score': 0.1714181485,
#            'outputs.gleu.gleu_score': 0.4285714286,
#            'outputs.meteor.meteor_score': 0.75,
#            'outputs.rouge.rouge_f1_score': 0.75,
#            'outputs.rouge.rouge_precision': 0.75,
#            'outputs.rouge.rouge_recall': 0.75}],
#  'studio_url': 'https://ai.azure.com/build/evaluation/bdc53495-35b0-493d-8d6f-88c51349aa2a?wsid=/subscriptions/65a513ce-bb5d-4ed5-92b1-fa601d510a15/resourceGroups/agentai/providers/Microsoft.MachineLearningServices/workspaces/eastus2project'}
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 16s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 32s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 1s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 2s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 4s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 8s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 16s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error INTERNAL SERVER ERROR encountered while exporting span batch, retrying in 32s.
